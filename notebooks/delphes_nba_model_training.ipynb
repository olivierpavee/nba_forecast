# %%
import pandas as pd

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor

# %%
nba = pd.read_csv("../nba_forecast/data/third_season_advanced.csv")
uni = pd.read_csv("../nba_forecast/data/last_ncaa_season.csv")
ratio = pd.read_csv("../nba_forecast/data/player_ratio_scores.csv")
athletics = pd.read_csv("../nba_forecast/data/final_athletics.csv")

# %%
print("Uni shape:", uni.shape)
print("NBA shape:", nba.shape)
print("Ratio shape:", ratio.shape)
# Out:
# Uni shape: (334, 30)
# NBA shape: (249, 27)
# Ratio shape: (334, 9)

# %%
nba.pos = nba.pos.apply(lambda x: x.split(",")[0])
nba.pos.unique()
# Out:
# array(['PF', 'SF', 'SG', 'PG', 'C'], dtype=object)

# %%
uni.columns
# Out:
# Index(['player_name', 'season', 'school_name', 'conf_abbr', 'g', 'gs', 'mp',
#        'per', 'ts_pct', 'efg_pct', 'fg3a_per_fga_pct', 'fta_per_fga_pct',
#        'pprod', 'orb_pct', 'drb_pct', 'trb_pct', 'ast_pct', 'stl_pct',
#        'blk_pct', 'tov_pct', 'usg_pct', 'ows', 'dws', 'ws', 'ws_per_40',
#        'obpm', 'dbpm', 'bpm', 'years', 'player_id'],
#       dtype='object')

# %%
uni.head()
# Out:
#               player_name   season school_name conf_abbr   g  gs    mp   per  \
# 0           Anthony Davis  2011-12    Kentucky       SEC  40  40  1281  35.1
# 1  Michael Kidd-Gilchrist  2011-12    Kentucky       SEC  40  39  1245  21.2
# 2            Bradley Beal  2011-12     Florida       SEC  37  37  1267  22.0
# 3            Dion Waiters  2011-12    Syracuse  Big East  37   0   891  26.3
# 4         Thomas Robinson  2011-12      Kansas    Big 12  39  39  1242  27.4
#
#    ts_pct  efg_pct  ...  usg_pct  ows  dws   ws  ws_per_40  obpm  dbpm   bpm  \
# 0   0.654    0.628  ...     18.8  5.9  4.1  9.9      0.310   9.1   8.1  17.2
# 1   0.570    0.511  ...     20.6  3.4  2.6  6.0      0.192   4.1   3.6   7.7
# 2   0.575    0.525  ...     23.0  3.6  2.1  5.7      0.180   5.4   2.9   8.4
# 3   0.565    0.534  ...     26.7  3.2  1.7  5.0      0.223   6.0   4.8  10.8
# 4   0.549    0.512  ...     30.0  3.7  3.5  7.2      0.231   5.4   3.4   8.8
#
#    years                 player_id
# 0      1           anthony-davis-5
# 1      1  michael-kidd-gilchrist-1
# 2      1            bradley-beal-1
# 3      2            dion-waiters-1
# 4      3         thomas-robinson-2
#
# [5 rows x 30 columns]

# %%
athletics.head()
# Out:
#   position  body_fat_pct  hand_length  hand_width  height_wo_shoes  \
# 0       PF           7.9          229         216             2064
# 1       SF           7.0          229         260             1975
# 2       SG           6.0          216         229             1911
# 3       SG           8.5          216         241             1892
# 4       PF           5.0          248         267             2026
#
#    height_w_shoes  standing_reach  weight  wingspan                 player_id
# 0            2096            2743   221.8      2273           anthony-davis-5
# 1            2019            2654   232.8      2134  michael-kidd-gilchrist-1
# 2            1949            2540   201.8      2032            bradley-beal-1
# 3            1930            2489   221.0      2013            dion-waiters-1
# 4            2051            2692   244.2      2216         thomas-robinson-2

# %%
trad_df = uni[["player_id"]].merge(nba[["age", "pos", "player_id"]], how = 'inner', on = 'player_id')
trad_df.rename(columns={"age": "nba_3rd_year_age"}, inplace=True)

trad_df["last_uni_age"] = trad_df.nba_3rd_year_age - 3

trad_df
# Out:
#                     player_id  nba_3rd_year_age pos  last_uni_age
# 0             anthony-davis-5                21  PF            18
# 1    michael-kidd-gilchrist-1                21  SF            18
# 2              bradley-beal-1                21  SG            18
# 3              dion-waiters-1                23  SG            20
# 4           thomas-robinson-2                23  PF            20
# ..                        ...               ...  ..           ...
# 243        keita-bates-diop-1                25  SF            22
# 244           chimezie-metu-1                23   C            20
# 245           alize-johnson-1                24  PF            21
# 246            malik-milton-1                24  SG            21
# 247    kostas-antetokounmpo-1                23  PF            20
#
# [248 rows x 4 columns]

# %%
uni = uni.merge(trad_df[["player_id", "pos", "last_uni_age"]], how = 'inner', on = 'player_id')
uni.head()
# Out:
#               player_name   season school_name conf_abbr   g  gs    mp   per  \
# 0           Anthony Davis  2011-12    Kentucky       SEC  40  40  1281  35.1
# 1  Michael Kidd-Gilchrist  2011-12    Kentucky       SEC  40  39  1245  21.2
# 2            Bradley Beal  2011-12     Florida       SEC  37  37  1267  22.0
# 3            Dion Waiters  2011-12    Syracuse  Big East  37   0   891  26.3
# 4         Thomas Robinson  2011-12      Kansas    Big 12  39  39  1242  27.4
#
#    ts_pct  efg_pct  ...  dws   ws  ws_per_40  obpm  dbpm   bpm  years  \
# 0   0.654    0.628  ...  4.1  9.9      0.310   9.1   8.1  17.2      1
# 1   0.570    0.511  ...  2.6  6.0      0.192   4.1   3.6   7.7      1
# 2   0.575    0.525  ...  2.1  5.7      0.180   5.4   2.9   8.4      1
# 3   0.565    0.534  ...  1.7  5.0      0.223   6.0   4.8  10.8      2
# 4   0.549    0.512  ...  3.5  7.2      0.231   5.4   3.4   8.8      3
#
#                   player_id  pos  last_uni_age
# 0           anthony-davis-5   PF            18
# 1  michael-kidd-gilchrist-1   SF            18
# 2            bradley-beal-1   SG            18
# 3            dion-waiters-1   SG            20
# 4         thomas-robinson-2   PF            20
#
# [5 rows x 32 columns]

# %%
off_features = ['last_uni_age', 'pos', 'per','ts_pct','fg3a_per_fga_pct','fta_per_fga_pct','orb_pct','ast_pct','tov_pct','usg_pct','ows','obpm']
def_features = ['last_uni_age', 'pos', 'stl_pct','blk_pct','dws','drb_pct','dbpm']
athletics_features = list(athletics)[1:-1]

# %%
athletics_features
# Out:
# ['body_fat_pct',
#  'hand_length',
#  'hand_width',
#  'height_wo_shoes',
#  'height_w_shoes',
#  'standing_reach',
#  'weight',
#  'wingspan']

# %%
# --- Check which features are unused

[col for col in nba.columns if col not in off_features + def_features]
# Out:
# ['player_id',
#  'name',
#  'season',
#  'age',
#  'team_id',
#  'games',
#  'minutes_played',
#  'trb_pct',
#  'ws',
#  'bpm',
#  'uni_url']

# %%
ratio = ratio[(ratio.player_id.isin(nba.player_id)) & (ratio.ratio_off.isna() == False)]
ratio
# Out:
#                     player_id             player_name pos  off_score  \
# 0             anthony-davis-5           Anthony Davis  PF       3.96
# 1    michael-kidd-gilchrist-1  Michael Kidd-Gilchrist  SF       2.68
# 2              bradley-beal-1            Bradley Beal  SG       2.73
# 3              dion-waiters-1            Dion Waiters  SG       2.36
# 4           thomas-robinson-2         Thomas Robinson  PF       2.68
# ..                        ...                     ...  ..        ...
# 240        keita-bates-diop-1        Keita Bates-Diop  SF       2.36
# 241           chimezie-metu-1           Chimezie Metu   C       2.67
# 242           alize-johnson-1           Alize Johnson  PF       3.29
# 243            malik-milton-1            Shake Milton  SG       2.91
# 244    kostas-antetokounmpo-1    Kostas Antetokounmpo  PF       1.86
#
#      def_score  uni_off_score  uni_def_score  ratio_off  ratio_def
# 0         3.34           3.68           3.79       1.08       0.88
# 1         1.89           2.73           1.96       0.98       0.96
# 2         1.71           2.93           1.99       0.93       0.86
# 3         1.49           2.97           2.04       0.79       0.73
# 4         2.17           3.03           2.67       0.88       0.81
# ..         ...            ...            ...        ...        ...
# 240       1.80           3.17           2.28       0.74       0.79
# 241       1.42           2.69           1.96       0.99       0.72
# 242       1.94           3.05           1.67       1.08       1.16
# 243       1.23           3.11           1.47       0.94       0.84
# 244       2.34           1.86           1.44       1.00       1.62
#
# [245 rows x 9 columns]

# %%
# --- Add athletics info to uni df

uni = uni.merge(athletics, how = 'inner', on = 'player_id')
uni.head()
# Out:
#               player_name   season school_name conf_abbr   g  gs    mp   per  \
# 0           Anthony Davis  2011-12    Kentucky       SEC  40  40  1281  35.1
# 1  Michael Kidd-Gilchrist  2011-12    Kentucky       SEC  40  39  1245  21.2
# 2            Bradley Beal  2011-12     Florida       SEC  37  37  1267  22.0
# 3            Dion Waiters  2011-12    Syracuse  Big East  37   0   891  26.3
# 4         Thomas Robinson  2011-12      Kansas    Big 12  39  39  1242  27.4
#
#    ts_pct  efg_pct  ...  last_uni_age  position  body_fat_pct  hand_length  \
# 0   0.654    0.628  ...            18        PF           7.9          229
# 1   0.570    0.511  ...            18        SF           7.0          229
# 2   0.575    0.525  ...            18        SG           6.0          216
# 3   0.565    0.534  ...            20        SG           8.5          216
# 4   0.549    0.512  ...            20        PF           5.0          248
#
#    hand_width  height_wo_shoes  height_w_shoes  standing_reach  weight  \
# 0         216             2064            2096            2743   221.8
# 1         260             1975            2019            2654   232.8
# 2         229             1911            1949            2540   201.8
# 3         241             1892            1930            2489   221.0
# 4         267             2026            2051            2692   244.2
#
#    wingspan
# 0      2273
# 1      2134
# 2      2032
# 3      2013
# 4      2216
#
# [5 rows x 41 columns]

# %%
X_off = uni[uni.player_id.isin(ratio.player_id)][off_features + athletics_features]
X_off = pd.get_dummies(X_off, columns=["pos"], prefix = "pos")

y_off = ratio.ratio_off

# %%
X_def = uni[uni.player_id.isin(ratio.player_id)][def_features + athletics_features]
X_def = pd.get_dummies(X_def, columns=["pos"], prefix = "pos")

y_def = ratio.ratio_def

# %%
off_scaler = RobustScaler().fit(X_off)
def_scaler = RobustScaler().fit(X_def)

X_off_scaled = off_scaler.transform(X_off)
X_def_scaled = def_scaler.transform(X_def)

# %%
X_off_train, X_off_test, y_off_train, y_off_test = train_test_split(X_off_scaled, y_off, test_size=0.2)
X_def_train, X_def_test, y_def_train, y_def_test = train_test_split(X_def_scaled, y_def, test_size=0.2)

# %%
lr_off = LinearRegression().fit(X_off_train, y_off_train)
lr_def = LinearRegression().fit(X_def_train, y_def_train)

# %%
print("LR off score:", round(lr_off.score(X_off_test, y_off_test), 3))
print("LR def score:", round(lr_def.score(X_def_test, y_def_test), 3))
# Out:
# LR off score: 0.347
# LR def score: -0.052

# %%
def evaluate(model, type_ = "off"):
    """
    Fit and evaluate a specific ML model on off / def dataset
    """
    
    print(f"Fitting {type(model).__name__} on {type_} dataset\n")
    
    if type_ != "off":
        model_ = model.fit(X_def_train, y_def_train)
        y_preds = model_.predict(X_def_test)
        
        df_preds_baseline = pd.DataFrame({"pred": [y_off_train.mean()]*len(y_off_test), "true": y_off_test})
        df_preds = pd.DataFrame({"pred": y_preds, "true": y_def_test})
        
        print(f"\tModel score: {round(model_.score(X_def_test, y_def_test), 3)}\n")
        
    else:
        model_ = model.fit(X_off_train, y_off_train)
        y_preds = model_.predict(X_off_test)
        
        df_preds_baseline = pd.DataFrame({"pred": [y_def_train.mean()]*len(y_def_test), "true": y_def_test})
        df_preds = pd.DataFrame({"pred": y_preds, "true": y_off_test})
        
        print(f"\tModel score: {round(model_.score(X_off_test, y_off_test), 3)}\n")

    
    df_preds["squared_error"] = (df_preds.true - df_preds.pred)**2
    df_preds_baseline["squared_error"] = (df_preds_baseline.true - df_preds_baseline.pred)**2

    print(f"\tBaseline MSE: {round(df_preds_baseline.squared_error.mean(), 3)}")
    print(f"\tModel MSE: {round(df_preds.squared_error.mean(), 3)}\n")

# %%
# --- Quickly evaluate regression models

evaluate(model=LinearRegression(), type_="def")
evaluate(model=LinearRegression(), type_="off")

evaluate(model=RandomForestRegressor(), type_="off")
# Out:
# Fitting LinearRegression on def dataset
#
# 	Model score: -0.052
#
# 	Baseline MSE: 0.04
# 	Model MSE: 0.052
#
# Fitting LinearRegression on off dataset
#
# 	Model score: 0.347
#
# 	Baseline MSE: 0.05
# 	Model MSE: 0.025
#
# Fitting RandomForestRegressor on off dataset
#
# 	Model score: 0.45
#
# 	Baseline MSE: 0.05
# 	Model MSE: 0.021

# %%
evaluate(model=Lasso(), type_="off")
# Out:
# Fitting Lasso on off dataset
#
# 	Model score: -0.042
#
# 	Baseline MSE: 0.05
# 	Model MSE: 0.04

# %%
evaluate(model=Ridge(), type_="off")
# Out:
# Fitting Ridge on off dataset
#
# 	Model score: 0.402
#
# 	Baseline MSE: 0.05
# 	Model MSE: 0.023

# %%
y_off_pred = lr_off.predict(X_off_test)

# %%
df_off_preds = pd.DataFrame({"pred": y_off_pred, "true": y_off_test})
df_off_preds["squared_error"] = (df_off_preds.true - df_off_preds.pred)**2

df_off_preds.squared_error.mean()
# Out:
# 0.026949690542335515

# %%
df_off_preds_baseline = pd.DataFrame({"pred": [y_off_train.mean()]*len(y_off_test), "true": y_off_test})
df_off_preds_baseline["squared_error"] = (df_off_preds_baseline.true - df_off_preds_baseline.pred)**2

df_off_preds_baseline.squared_error.mean()
# Out:
# 0.044927113702623915

# %%
df_off_preds
# Out:
#          pred  true  squared_error
# 197  1.068261  0.96       0.011721
# 154  1.011488  0.93       0.006640
# 8    1.272061  1.57       0.088767
# 90   0.824120  0.65       0.030318
# 205  1.019940  0.92       0.009988
# 26   0.740842  0.73       0.000118
# 147  0.948629  0.94       0.000074
# 50   1.103031  1.02       0.006894
# 89   0.779473  0.76       0.000379
# 146  0.953695  1.04       0.007449
# 12   1.234255  1.17       0.004129
# 67   1.043093  0.93       0.012790
# 70   0.844201  0.86       0.000250
# 92   1.066686  0.81       0.065888
# 53   0.841925  1.00       0.024988
# 72   0.933215  1.04       0.011403
# 94   0.724496  0.83       0.011131
# 68   0.843616  0.69       0.023598
# 14   1.103609  0.96       0.020624
# 115  1.055932  1.09       0.001161
# 9    1.080456  0.95       0.017019
# 62   1.135447  1.08       0.003074
# 28   0.664366  0.79       0.015784
# 25   1.086926  1.23       0.020470
# 24   1.326742  1.11       0.046977
# 97   1.030938  0.85       0.032738
# 235  1.048330  1.08       0.001003
# 182  0.926947  0.85       0.005921
# 217  0.878226  0.94       0.003816
# 242  0.829729  1.08       0.062636
# 148  0.660155  0.71       0.002484
# 110  1.121310  1.11       0.000128
# 43   0.918708  0.83       0.007869
# 118  0.738891  0.82       0.006579
# 30   0.776497  0.62       0.024491
# 188  1.025129  0.61       0.172332
# 213  0.863170  0.99       0.016086
# 177  0.943151  0.87       0.005351
# 240  0.898396  0.74       0.025089
# 140  1.041084  1.12       0.006228
# 218  0.861291  0.64       0.048970
# 181  1.157057  0.87       0.082402
# 200  0.833536  0.78       0.002866
# 133  0.957350  0.96       0.000007
# 37   0.910249  0.38       0.281164
# 105  1.004225  0.74       0.069815
# 117  0.831725  0.70       0.017352
# 243  0.948047  0.94       0.000065
# 66   0.489266  0.43       0.003512
