# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

# %%
team_2011_df = pd.read_csv('../nba_forecast/data/team_stats_2011.csv')
team_2011_df.rename(columns={"Team":"team"}, inplace=True)

po_2011_df = pd.read_csv('../nba_forecast/data/pick_order_2011.csv')

team_2011_df = team_2011_df.merge(po_2011_df, how = 'inner', on = 'team').drop(columns='team_name')

team_2011_df['off_rtg'] = 1/team_2011_df['off_rtg']

scaler = MinMaxScaler()
team_2011_df[['off_rtg']] = scaler.fit_transform(team_2011_df[['off_rtg']])

team_2011_df[['def_rtg']] = scaler.fit_transform(team_2011_df[['def_rtg']])

team_2011_df
# Out:
#    team   off_rtg   def_rtg  off_rank  def_rank  pace attendance  \
# 0   BOS  0.594362  0.000000        27         1  90.4    614,592
# 1   BRK  0.471424  0.934426        23        28  90.1    460,719
# 2   TOR  0.607573  0.516393        29        14  89.3    555,584
# 3   PHI  0.408526  0.081967        20         3  89.7    577,597
# 4   NYK  0.377529  0.229508        17         5  93.2    652,179
# 5   CHI  0.197606  0.008197         5         2  89.1    731,326
# 6   CLE  0.587776  0.877049        24        26  91.3    525,577
# 7   DET  0.594362  0.663934        26        22  89.2    475,638
# 8   IND  0.238683  0.401639         7         9  90.7    467,561
# 9   MIL  0.310369  0.573770        13        16  93.7    485,717
# 10  WAS  0.594362  0.655738        25        21  92.5    552,038
# 11  ATL  0.346827  0.245902        16         6  90.2    501,593
# 12  ORL  0.340722  0.483607        15        12  89.0    623,587
# ...

# %% [markdown]
# > FIT SCORE = ( Toff_rtg x Pratio_off x Pscore_uni_off ) + ( Tdef_rtg x Pratio_def x Pscore_uni_def )
